# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dados = {
    "Produto": ["A", "B", "C"],
    "Vendas": [100, 200, 150]
}

df = pd.DataFrame(dados)

df
# Out:
#   Produto  Vendas
# 0       A     100
# 1       B     200
# 2       C     150
